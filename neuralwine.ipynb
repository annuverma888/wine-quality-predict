# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
import numpy as np 
import pandas as pd
df = pd.read_csv('wine.csv')
df.head()
y=df['quality']
x=df.drop('quality',axis=1)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=(64,32),activation='relu',max_iter=500)
model.fit(x_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500)

# %%
print(model.score(x_test,y_test))
# Out:
# 0.585

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = model.predict(x_test)

cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[  0   0   1   0   0   0]
#  [  0   0  11   2   0   0]
#  [  0   1 130  30   3   0]
#  [  0   0  66  88  15   0]
#  [  0   0   3  29  16   0]
#  [  0   0   0   3   2   0]]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1199, 11)
# (400, 11)
# (1199,)
# (400,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(64, input_dim=11, activation='relu'))  #activation 


model.add(Dense(6, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])   #optimizer task - classification
#optimizer - Adam is an optimization algorithm that can be used instead of the classical stochastic
# gradient descent procedure to update network weights iteratively based on training data.
# It combines the advantages of two other extensions of stochastic gradient descent,
# namely Adaptive Gradient Algorithm (AdaGrad) and Root Mean Square Propagation (RMSProp).
#loss - The loss function used here is 'sparse_categorical_crossentropy',
# which is suitable for multi-class classification problems where the target labels are integers.
# It calculates the cross-entropy loss between the true labels and the predicted probabilities.
#metrics - The model is evaluated
# using the 'accuracy' metric, which measures the proportion of correctly classified samples.
model.summary()
y_train=y_train-3
#why we are doing this because the quality of wine is in the range of 3-8 and we have to convert it into 0-5 for the model to work properly.
y_test=y_test-3 
#why we are doing this because the quality of wine is in the range of 3-8 and we have to convert it into 0-5 for the model to work properly.

print(np.unique(y_train))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\annu3\OneDrive\Desktop\aiml_Internship\aiml_internship\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,158 (4.52 KB)
#  Trainable params: 1,158 (4.52 KB)
#  Non-trainable params: 0 (0.00 B)
# [0 1 2 3 4 5]

# %%
model.fit(x_train,y_train,epochs=100,batch_size=32,validation_data=(x_test,y_test))
#validation_split- 0.2 means 20% of the training data will be used for validation.
#epochs- The model will be trained for 100 epochs, meaning it will iterate over the entire training dataset 100 times.
# Out:
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3561 - loss: 3.0556 - val_accuracy: 0.3975 - val_loss: 1.3011
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4812 - loss: 1.2160 - val_accuracy: 0.4275 - val_loss: 1.2116
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4887 - loss: 1.1647 - val_accuracy: 0.4525 - val_loss: 1.1699
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4896 - loss: 1.1513 - val_accuracy: 0.4825 - val_loss: 1.1517
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4937 - loss: 1.1373 - val_accuracy: 0.4400 - val_loss: 1.1537
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4946 - loss: 1.1326 - val_accuracy: 0.4600 - val_loss: 1.1708
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4904 - loss: 1.1400 - val_accuracy: 0.4575 - val_loss: 1.1380
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5021 - loss: 1.1236 - val_accuracy: 0.4825 - val_loss: 1.1233
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4971 - loss: 1.1107 - val_accuracy: 0.4750 - val_loss: 1.1167
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4912 - loss: 1.1147 - val_accuracy: 0.4300 - val_loss: 1.1776
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5038 - loss: 1.1136 - val_accuracy: 0.4400 - val_loss: 1.1341
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5038 - loss: 1.1106 - val_accuracy: 0.4700 - val_loss: 1.1230
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5138 - loss: 1.0887 - val_accuracy: 0.4725 - val_loss: 1.0939
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5138 - loss: 1.0781 - val_accuracy: 0.5000 - val_loss: 1.0925
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5254 - loss: 1.0795 - val_accuracy: 0.4975 - val_loss: 1.0775
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5054 - loss: 1.1022 - val_accuracy: 0.4700 - val_loss: 1.0997
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5254 - loss: 1.0664 - val_accuracy: 0.4425 - val_loss: 1.1389
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5321 - loss: 1.0718 - val_accuracy: 0.4525 - val_loss: 1.1175
# Epoch 19/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5213 - loss: 1.0639 - val_accuracy: 0.4800 - val_loss: 1.0829
# Epoch 20/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5263 - loss: 1.0619 - val_accuracy: 0.4850 - val_loss: 1.0924
# Epoch 21/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5246 - loss: 1.0627 - val_accuracy: 0.5100 - val_loss: 1.0604
# Epoch 22/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5463 - loss: 1.0513 - val_accuracy: 0.5225 - val_loss: 1.0565
# Epoch 23/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5405 - loss: 1.0415 - val_accuracy: 0.5025 - val_loss: 1.0934
# Epoch 24/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5246 - loss: 1.0527 - val_accuracy: 0.5025 - val_loss: 1.0597
# Epoch 25/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5463 - loss: 1.0403 - val_accuracy: 0.4950 - val_loss: 1.0685
# Epoch 26/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5379 - loss: 1.0476 - val_accuracy: 0.4925 - val_loss: 1.0492
# Epoch 27/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5546 - loss: 1.0339 - val_accuracy: 0.5125 - val_loss: 1.0681
# Epoch 28/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5338 - loss: 1.0574 - val_accuracy: 0.4975 - val_loss: 1.0927
# Epoch 29/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5605 - loss: 1.0390 - val_accuracy: 0.4975 - val_loss: 1.0537
# Epoch 30/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5455 - loss: 1.0430 - val_accuracy: 0.4850 - val_loss: 1.1085
# Epoch 31/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5588 - loss: 1.0323 - val_accuracy: 0.5225 - val_loss: 1.0285
# Epoch 32/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5588 - loss: 1.0236 - val_accuracy: 0.5025 - val_loss: 1.0385
# Epoch 33/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5546 - loss: 1.0209 - val_accuracy: 0.5100 - val_loss: 1.0625
# Epoch 34/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5555 - loss: 1.0252 - val_accuracy: 0.5075 - val_loss: 1.0650
# Epoch 35/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5546 - loss: 1.0330 - val_accuracy: 0.5325 - val_loss: 1.0203
# Epoch 36/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5646 - loss: 1.0134 - val_accuracy: 0.5250 - val_loss: 1.0308
# Epoch 37/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5705 - loss: 1.0027 - val_accuracy: 0.5325 - val_loss: 1.0196
# Epoch 38/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5913 - loss: 1.0061 - val_accuracy: 0.5250 - val_loss: 1.0192
# Epoch 39/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5655 - loss: 1.0015 - val_accuracy: 0.5300 - val_loss: 1.0263
# Epoch 40/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5621 - loss: 0.9976 - val_accuracy: 0.5275 - val_loss: 1.0200
# Epoch 41/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5688 - loss: 1.0084 - val_accuracy: 0.4925 - val_loss: 1.0883
# Epoch 42/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5555 - loss: 1.0220 - val_accuracy: 0.5225 - val_loss: 1.0177
# Epoch 43/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5755 - loss: 1.0002 - val_accuracy: 0.5200 - val_loss: 1.0335
# Epoch 44/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5872 - loss: 0.9957 - val_accuracy: 0.5300 - val_loss: 1.0126
# Epoch 45/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5730 - loss: 0.9971 - val_accuracy: 0.5275 - val_loss: 1.0083
# Epoch 46/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5897 - loss: 0.9918 - val_accuracy: 0.5225 - val_loss: 1.0137
# Epoch 47/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5796 - loss: 1.0012 - val_accuracy: 0.5250 - val_loss: 1.0077
# Epoch 48/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5596 - loss: 1.0062 - val_accuracy: 0.5350 - val_loss: 1.0386
# Epoch 49/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5705 - loss: 1.0123 - val_accuracy: 0.5200 - val_loss: 1.0431
# Epoch 50/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5730 - loss: 0.9953 - val_accuracy: 0.5375 - val_loss: 1.0066
# Epoch 51/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5813 - loss: 0.9812 - val_accuracy: 0.5475 - val_loss: 1.0060
# Epoch 52/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5763 - loss: 0.9845 - val_accuracy: 0.5200 - val_loss: 1.0092
# Epoch 53/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5663 - loss: 0.9999 - val_accuracy: 0.5275 - val_loss: 1.0487
# Epoch 54/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5755 - loss: 0.9839 - val_accuracy: 0.5100 - val_loss: 1.0446
# Epoch 55/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5838 - loss: 0.9829 - val_accuracy: 0.5525 - val_loss: 0.9997
# Epoch 56/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5905 - loss: 0.9715 - val_accuracy: 0.5350 - val_loss: 0.9900
# Epoch 57/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5696 - loss: 0.9845 - val_accuracy: 0.5225 - val_loss: 1.0013
# Epoch 58/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5671 - loss: 0.9854 - val_accuracy: 0.5300 - val_loss: 0.9973
# Epoch 59/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5771 - loss: 0.9779 - val_accuracy: 0.5275 - val_loss: 1.0063
# Epoch 60/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5997 - loss: 0.9680 - val_accuracy: 0.5425 - val_loss: 1.0026
# Epoch 61/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5988 - loss: 0.9663 - val_accuracy: 0.5100 - val_loss: 1.0267
# Epoch 62/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5763 - loss: 0.9720 - val_accuracy: 0.5700 - val_loss: 0.9909
# Epoch 63/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5872 - loss: 0.9720 - val_accuracy: 0.5175 - val_loss: 1.0146
# Epoch 64/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5905 - loss: 0.9733 - val_accuracy: 0.5350 - val_loss: 0.9866
# Epoch 65/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6080 - loss: 0.9620 - val_accuracy: 0.4750 - val_loss: 1.0307
# Epoch 66/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5822 - loss: 0.9747 - val_accuracy: 0.5475 - val_loss: 0.9818
# Epoch 67/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5880 - loss: 0.9551 - val_accuracy: 0.5200 - val_loss: 0.9987
# Epoch 68/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5897 - loss: 0.9640 - val_accuracy: 0.5475 - val_loss: 0.9834
# Epoch 69/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5888 - loss: 0.9725 - val_accuracy: 0.5375 - val_loss: 0.9875
# Epoch 70/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5905 - loss: 0.9657 - val_accuracy: 0.5350 - val_loss: 0.9925
# Epoch 71/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5997 - loss: 0.9551 - val_accuracy: 0.5350 - val_loss: 0.9853
# Epoch 72/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6022 - loss: 0.9521 - val_accuracy: 0.5700 - val_loss: 0.9831
# Epoch 73/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6005 - loss: 0.9575 - val_accuracy: 0.5425 - val_loss: 0.9749
# Epoch 74/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5847 - loss: 0.9623 - val_accuracy: 0.5675 - val_loss: 0.9762
# Epoch 75/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6022 - loss: 0.9543 - val_accuracy: 0.5700 - val_loss: 0.9760
# Epoch 76/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6038 - loss: 0.9586 - val_accuracy: 0.5550 - val_loss: 0.9821
# Epoch 77/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6113 - loss: 0.9470 - val_accuracy: 0.5500 - val_loss: 1.0011
# Epoch 78/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6022 - loss: 0.9492 - val_accuracy: 0.5575 - val_loss: 0.9769
# Epoch 79/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5980 - loss: 0.9541 - val_accuracy: 0.5550 - val_loss: 0.9729
# Epoch 80/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6105 - loss: 0.9434 - val_accuracy: 0.5750 - val_loss: 0.9793
# Epoch 81/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6063 - loss: 0.9467 - val_accuracy: 0.5350 - val_loss: 0.9923
# Epoch 82/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6080 - loss: 0.9458 - val_accuracy: 0.5450 - val_loss: 0.9863
# Epoch 83/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6147 - loss: 0.9467 - val_accuracy: 0.5600 - val_loss: 0.9842
# Epoch 84/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5880 - loss: 0.9484 - val_accuracy: 0.5350 - val_loss: 1.0018
# Epoch 85/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5763 - loss: 0.9723 - val_accuracy: 0.5700 - val_loss: 0.9652
# Epoch 86/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6172 - loss: 0.9467 - val_accuracy: 0.5475 - val_loss: 0.9640
# Epoch 87/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6047 - loss: 0.9459 - val_accuracy: 0.5500 - val_loss: 0.9584
# Epoch 88/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5897 - loss: 0.9462 - val_accuracy: 0.5500 - val_loss: 1.0047
# Epoch 89/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6113 - loss: 0.9348 - val_accuracy: 0.5800 - val_loss: 0.9637
# Epoch 90/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5813 - loss: 0.9510 - val_accuracy: 0.5350 - val_loss: 0.9858
# Epoch 91/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 0.9454 - val_accuracy: 0.5625 - val_loss: 0.9702
# Epoch 92/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5980 - loss: 0.9424 - val_accuracy: 0.5625 - val_loss: 0.9744
# Epoch 93/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6105 - loss: 0.9391 - val_accuracy: 0.5500 - val_loss: 0.9688
# Epoch 94/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6022 - loss: 0.9477 - val_accuracy: 0.5350 - val_loss: 1.0074
# Epoch 95/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6080 - loss: 0.9441 - val_accuracy: 0.5675 - val_loss: 0.9642
# Epoch 96/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5988 - loss: 0.9297 - val_accuracy: 0.5675 - val_loss: 0.9669
# Epoch 97/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6155 - loss: 0.9229 - val_accuracy: 0.5250 - val_loss: 1.0164
# Epoch 98/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5905 - loss: 0.9365 - val_accuracy: 0.5650 - val_loss: 0.9513
# Epoch 99/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5972 - loss: 0.9404 - val_accuracy: 0.5450 - val_loss: 0.9862
# Epoch 100/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6097 - loss: 0.9436 - val_accuracy: 0.5600 - val_loss: 0.9788

# %%
pred = model.predict(x_test)
pred=np.argmax(pred,axis=1)
pred=pred+3
print(pred)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [5 5 5 5 6 5 5 5 6 6 6 5 5 5 5 7 5 5 7 5 5 5 6 6 5 5 6 5 5 6 5 6 6 5 5 5 6
#  6 5 7 5 5 6 5 6 5 6 5 5 6 5 5 6 6 5 5 6 5 6 5 5 6 5 5 6 5 7 5 6 5 6 5 6 6
#  6 5 6 5 6 6 5 7 5 6 6 6 5 6 6 5 6 5 6 5 5 6 5 6 5 5 5 5 6 7 6 6 6 5 6 5 6
#  5 7 5 6 6 7 5 5 6 6 5 6 5 5 5 6 5 5 6 6 5 5 7 6 5 5 5 5 6 6 6 6 5 6 5 6 6
#  6 5 6 7 5 6 6 6 5 6 5 6 6 5 6 5 5 5 5 5 5 5 5 5 6 5 5 5 6 5 5 5 5 6 5 7 5
#  6 5 5 7 5 6 5 6 6 5 5 5 5 5 6 5 5 5 5 7 6 5 5 6 7 6 5 6 7 6 6 5 5 6 5 5 6
#  6 6 5 5 5 7 5 5 5 5 7 6 5 6 5 6 5 5 6 5 5 7 5 5 6 5 7 5 5 5 5 5 5 5 6 6 5
#  6 6 7 5 7 6 6 5 5 6 6 5 5 5 5 5 6 6 5 6 5 6 5 5 5 5 6 5 6 5 6 5 7 6 5 5 7
#  5 7 6 7 5 5 6 5 5 5 6 6 7 7 5 5 5 5 5 6 5 5 6 5 5 5 6 5 5 5 6 5 5 6 6 7 5
#  5 6 6 6 7 5 5 6 7 6 5 6 5 6 5 5 6 5 7 5 5 5 5 5 5 5 6 6 5 5 5 5 6 6 5 5 5
#  5 5 6 6 5 7 5 6 5 5 5 6 7 5 6 6 6 5 5 5 6 5 5 5 6 6 7 5 5 6]

# %%
model.save('wine_quality_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt 
plt.plot(model.history.history['accuracy'],label ='train')
plt.plot(model.history.history['val_accuracy'],label='validation')
plt.xlabel('Epoch')
plt.ylabel=('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot(model.history.history['loss'],label ='train')
plt.plot(model.history.history['val_loss'],label='validation')
plt.xlabel('Epoch')
plt.ylabel=('loss')
plt.legend()
plt.show()
