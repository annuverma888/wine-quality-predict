# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
import numpy as np 
import pandas as pd
df = pd.read_csv('wine.csv')
df.head()
y=df['quality']
x=df.drop('quality',axis=1)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=(64,32),activation='relu',max_iter=500)
model.fit(x_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500)

# %%
print(model.score(x_test,y_test))
# Out:
# 0.555

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = model.predict(x_test)

cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[  0   0   1   0   0   0]
#  [  0   0  11   2   0   0]
#  [  0   0 130  31   3   0]
#  [  0   0  78  71  20   0]
#  [  0   0   4  23  21   0]
#  [  0   0   0   2   3   0]]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1199, 11)
# (400, 11)
# (1199,)
# (400,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(64, input_dim=11, activation='relu'))


model.add(Dense(6, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])   #optimizer task - classification
#optimizer - Adam is an optimization algorithm that can be used instead of the classical stochastic
# gradient descent procedure to update network weights iteratively based on training data.
# It combines the advantages of two other extensions of stochastic gradient descent,
# namely Adaptive Gradient Algorithm (AdaGrad) and Root Mean Square Propagation (RMSProp).
#loss - The loss function used here is 'sparse_categorical_crossentropy',
# which is suitable for multi-class classification problems where the target labels are integers.
# It calculates the cross-entropy loss between the true labels and the predicted probabilities.
#metrics - The model is evaluated using the 'accuracy' metric, which measures the proportion of correctly classified samples.
model.summary()
y_train=y_train-3
#why we are doing this because the quality of wine is in the range of 3-8 and we have to convert it into 0-5 for the model to work properly.
y_test=y_test-3 
#why we are doing this because the quality of wine is in the range of 3-8 and we have to convert it into 0-5 for the model to work properly.

print(np.unique(y_train))
# Out:
# c:\Users\annu3\OneDrive\Desktop\aiml_Internship\aiml_internship\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,158 (4.52 KB)
#  Trainable params: 1,158 (4.52 KB)
#  Non-trainable params: 0 (0.00 B)
# [0 1 2 3 4 5]

# %%
model.fit(x_train,y_train,epochs=100,batch_size=32,validation_data=(x_test,y_test))
#validation_split- 0.2 means 20% of the training data will be used for validation.
#epochs- The model will be trained for 100 epochs, meaning it will iterate over the entire training dataset 100 times.
# Out:
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3186 - loss: 2.8186 - val_accuracy: 0.3875 - val_loss: 1.5802
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4070 - loss: 1.3942 - val_accuracy: 0.4550 - val_loss: 1.2770
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4629 - loss: 1.2275 - val_accuracy: 0.4625 - val_loss: 1.2074
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4737 - loss: 1.1814 - val_accuracy: 0.4925 - val_loss: 1.1767
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4862 - loss: 1.1693 - val_accuracy: 0.4975 - val_loss: 1.1525
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4971 - loss: 1.1519 - val_accuracy: 0.4875 - val_loss: 1.1447
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4996 - loss: 1.1450 - val_accuracy: 0.4875 - val_loss: 1.1422
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5029 - loss: 1.1464 - val_accuracy: 0.4425 - val_loss: 1.1875
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4846 - loss: 1.1344 - val_accuracy: 0.4900 - val_loss: 1.1239
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5071 - loss: 1.1193 - val_accuracy: 0.4875 - val_loss: 1.1282
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5179 - loss: 1.1114 - val_accuracy: 0.5000 - val_loss: 1.1163
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5121 - loss: 1.1110 - val_accuracy: 0.4700 - val_loss: 1.1352
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5163 - loss: 1.1106 - val_accuracy: 0.5150 - val_loss: 1.1113
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5213 - loss: 1.0970 - val_accuracy: 0.4325 - val_loss: 1.1753
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5163 - loss: 1.1083 - val_accuracy: 0.4975 - val_loss: 1.1066
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5388 - loss: 1.0900 - val_accuracy: 0.4375 - val_loss: 1.1781
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5238 - loss: 1.0965 - val_accuracy: 0.5100 - val_loss: 1.1288
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5513 - loss: 1.0650 - val_accuracy: 0.5025 - val_loss: 1.0865
# Epoch 19/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5446 - loss: 1.0717 - val_accuracy: 0.5100 - val_loss: 1.0813
# Epoch 20/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5463 - loss: 1.0785 - val_accuracy: 0.5050 - val_loss: 1.0985
# Epoch 21/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5446 - loss: 1.0596 - val_accuracy: 0.5025 - val_loss: 1.0738
# Epoch 22/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5379 - loss: 1.0738 - val_accuracy: 0.4975 - val_loss: 1.0807
# Epoch 23/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5488 - loss: 1.0555 - val_accuracy: 0.5100 - val_loss: 1.0694
# Epoch 24/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5680 - loss: 1.0472 - val_accuracy: 0.5150 - val_loss: 1.0594
# Epoch 25/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5413 - loss: 1.0800 - val_accuracy: 0.5075 - val_loss: 1.0869
# Epoch 26/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5480 - loss: 1.0589 - val_accuracy: 0.5100 - val_loss: 1.0549
# Epoch 27/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5588 - loss: 1.0496 - val_accuracy: 0.4850 - val_loss: 1.1224
# Epoch 28/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5688 - loss: 1.0346 - val_accuracy: 0.5275 - val_loss: 1.0474
# Epoch 29/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5471 - loss: 1.0340 - val_accuracy: 0.5250 - val_loss: 1.0429
# Epoch 30/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5746 - loss: 1.0269 - val_accuracy: 0.5300 - val_loss: 1.0371
# Epoch 31/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5663 - loss: 1.0333 - val_accuracy: 0.4875 - val_loss: 1.1104
# Epoch 32/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5580 - loss: 1.0425 - val_accuracy: 0.5225 - val_loss: 1.0608
# Epoch 33/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5630 - loss: 1.0313 - val_accuracy: 0.5300 - val_loss: 1.0391
# Epoch 34/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5638 - loss: 1.0190 - val_accuracy: 0.5350 - val_loss: 1.0277
# Epoch 35/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5738 - loss: 1.0198 - val_accuracy: 0.5375 - val_loss: 1.0267
# Epoch 36/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5746 - loss: 1.0123 - val_accuracy: 0.5175 - val_loss: 1.0406
# Epoch 37/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5755 - loss: 1.0129 - val_accuracy: 0.5300 - val_loss: 1.0372
# Epoch 38/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5638 - loss: 1.0206 - val_accuracy: 0.5350 - val_loss: 1.0382
# Epoch 39/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5580 - loss: 1.0280 - val_accuracy: 0.5500 - val_loss: 1.0307
# Epoch 40/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5880 - loss: 1.0085 - val_accuracy: 0.5125 - val_loss: 1.0629
# Epoch 41/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5822 - loss: 1.0135 - val_accuracy: 0.5525 - val_loss: 1.0380
# Epoch 42/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5588 - loss: 1.0138 - val_accuracy: 0.5075 - val_loss: 1.0809
# Epoch 43/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5546 - loss: 1.0240 - val_accuracy: 0.5300 - val_loss: 1.0220
# Epoch 44/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5838 - loss: 1.0004 - val_accuracy: 0.5050 - val_loss: 1.0956
# Epoch 45/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5746 - loss: 1.0164 - val_accuracy: 0.5450 - val_loss: 1.0124
# Epoch 46/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5588 - loss: 1.0174 - val_accuracy: 0.5475 - val_loss: 1.0146
# Epoch 47/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5705 - loss: 1.0013 - val_accuracy: 0.5175 - val_loss: 1.0773
# Epoch 48/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5755 - loss: 1.0028 - val_accuracy: 0.5325 - val_loss: 1.0159
# Epoch 49/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5563 - loss: 1.0099 - val_accuracy: 0.5000 - val_loss: 1.0386
# Epoch 50/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5805 - loss: 1.0004 - val_accuracy: 0.5450 - val_loss: 1.0124
# Epoch 51/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5696 - loss: 1.0002 - val_accuracy: 0.5525 - val_loss: 0.9992
# Epoch 52/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5872 - loss: 0.9922 - val_accuracy: 0.5600 - val_loss: 0.9890
# Epoch 53/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5713 - loss: 0.9913 - val_accuracy: 0.5675 - val_loss: 0.9892
# Epoch 54/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5713 - loss: 1.0026 - val_accuracy: 0.5125 - val_loss: 1.0529
# Epoch 55/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5738 - loss: 0.9904 - val_accuracy: 0.5525 - val_loss: 1.0129
# Epoch 56/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5872 - loss: 0.9779 - val_accuracy: 0.5525 - val_loss: 0.9901
# Epoch 57/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5872 - loss: 0.9738 - val_accuracy: 0.5550 - val_loss: 0.9987
# Epoch 58/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5980 - loss: 0.9820 - val_accuracy: 0.5600 - val_loss: 0.9921
# Epoch 59/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5688 - loss: 0.9853 - val_accuracy: 0.5300 - val_loss: 1.0195
# Epoch 60/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5705 - loss: 0.9767 - val_accuracy: 0.5275 - val_loss: 0.9891
# Epoch 61/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5897 - loss: 0.9705 - val_accuracy: 0.5600 - val_loss: 0.9822
# Epoch 62/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5922 - loss: 0.9813 - val_accuracy: 0.5425 - val_loss: 1.0239
# Epoch 63/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5980 - loss: 0.9733 - val_accuracy: 0.5650 - val_loss: 0.9867
# Epoch 64/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5955 - loss: 0.9712 - val_accuracy: 0.5575 - val_loss: 0.9747
# Epoch 65/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5880 - loss: 0.9728 - val_accuracy: 0.5375 - val_loss: 1.0057
# Epoch 66/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5721 - loss: 1.0024 - val_accuracy: 0.5650 - val_loss: 0.9843
# Epoch 67/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5930 - loss: 0.9729 - val_accuracy: 0.5600 - val_loss: 1.0040
# Epoch 68/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5988 - loss: 0.9612 - val_accuracy: 0.5450 - val_loss: 0.9871
# Epoch 69/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6072 - loss: 0.9574 - val_accuracy: 0.5700 - val_loss: 1.0017
# Epoch 70/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6022 - loss: 0.9701 - val_accuracy: 0.5550 - val_loss: 0.9901
# Epoch 71/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5771 - loss: 0.9727 - val_accuracy: 0.5550 - val_loss: 0.9876
# Epoch 72/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5913 - loss: 0.9738 - val_accuracy: 0.5625 - val_loss: 0.9754
# Epoch 73/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5847 - loss: 0.9695 - val_accuracy: 0.5650 - val_loss: 0.9752
# Epoch 74/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5796 - loss: 0.9641 - val_accuracy: 0.5225 - val_loss: 1.0092
# Epoch 75/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5888 - loss: 0.9565 - val_accuracy: 0.5375 - val_loss: 0.9912
# Epoch 76/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6022 - loss: 0.9550 - val_accuracy: 0.5600 - val_loss: 0.9710
# Epoch 77/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5905 - loss: 0.9645 - val_accuracy: 0.5525 - val_loss: 0.9773
# Epoch 78/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5913 - loss: 0.9602 - val_accuracy: 0.5800 - val_loss: 0.9627
# Epoch 79/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 0.9613 - val_accuracy: 0.5675 - val_loss: 0.9735
# Epoch 80/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5780 - loss: 0.9708 - val_accuracy: 0.5600 - val_loss: 0.9633
# Epoch 81/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5938 - loss: 0.9526 - val_accuracy: 0.5525 - val_loss: 0.9694
# Epoch 82/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5947 - loss: 0.9583 - val_accuracy: 0.5600 - val_loss: 0.9740
# Epoch 83/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5880 - loss: 0.9515 - val_accuracy: 0.5775 - val_loss: 0.9622
# Epoch 84/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6072 - loss: 0.9462 - val_accuracy: 0.5475 - val_loss: 0.9756
# Epoch 85/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5880 - loss: 0.9661 - val_accuracy: 0.5825 - val_loss: 0.9608
# Epoch 86/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5947 - loss: 0.9629 - val_accuracy: 0.5650 - val_loss: 0.9731
# Epoch 87/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5980 - loss: 0.9611 - val_accuracy: 0.5625 - val_loss: 0.9639
# Epoch 88/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5972 - loss: 0.9584 - val_accuracy: 0.5350 - val_loss: 0.9890
# Epoch 89/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0